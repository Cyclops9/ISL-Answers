# %% [markdown]
# 3.7 Exercises
# Conceptual
# 1. Describe the null hypotheses to which the p-values given in Table 3.4
# correspond. Explain what conclusions you can draw based on these
# p-values. Your explanation should be phrased in terms of sales, TV,
# radio, and newspaper, rather than in terms of the coefficients of the
# linear model

# %% [markdown]
# ![table3.4.png](attachment:image.png)

# %% [markdown]
#     - H0: Coefficient of the related variable (intercept, tv, radio or newspaper) is zero
#     H1: Coefficient is different than zero.
#     - p-value of TV says, effect of TV is different than zero, it means its statistically significant to the model. For radio it is the same. For newspaper, we can not reject the null hypothesis as its p-value is 0.8599, it means effect of newspaper is not different than 0 on sales.

# %% [markdown]
# 2. Carefully explain the differences between the KNN classifier and KNN
# regression methods.

# %% [markdown]
#     - KNN classifier, classifies the given features according to closest neighbours, KNN regression method, makes a prediction with given features by taking the average of the closest neighbours.

# %% [markdown]
# 3. Suppose we have a data set with five predictors, X1 = GPA, X2 =
# IQ, X3 = Level (1 for College and 0 for High School), X4 = Interaction between GPA and IQ, and X5 = Interaction between GPA and
# Level. The response is starting salary after graduation (in thousands
# of dollars). Suppose we use least squares to fit the model, and get
# βˆ0 = 50, βˆ1 = 20, βˆ2 = 0.07, βˆ3 = 35, βˆ4 = 0.01, βˆ5 = −10.
# (a) Which answer is correct, and why?
#
# i. For a fixed value of IQ and GPA, high school graduates earn
# more, on average, than college graduates.
#
# ii. For a fixed value of IQ and GPA, college graduates earn
# more, on average, than high school graduates.
#
# iii. For a fixed value of IQ and GPA, high school graduates earn
# more, on average, than college graduates provided that the
# GPA is high enough.
#
# iv. For a fixed value of IQ and GPA, college graduates earn
# more, on average, than high school graduates provided that
# the GPA is high enough.

# %% [markdown]
# - High School Graduates: B0 + B1*x1 + B2*x2 + B3*0 + B4*x4 + B5*0
#   College Graduates: B0 + B1*x1 + B2*x2 + B3*1 + B4*x4 + B5*(x1*1)
# - As terms with B0, B1, B2 and B4 the same, we have left with B3*0 + B5*0 and B3*1 + B5*x1, B3 is 35 which means with higher than 3.5 GPA college graduates earns less than high school graduates, however less than 3.5 GPA college graduates, earns higher. Which means iii is correct.

# %% [markdown]
# (b) Predict the salary of a college graduate with IQ of 110 and a
# GPA of 4.0
#
# - 137.1K

# %%
salary = 50 + 20 * 4.0 + 110*0.07 + 35 * 1 + 0.01* (4.0*110) + (-10)*(4.0*1)
print(salary)
# Out:
# 137.1

# %% [markdown]
# (c) True or false: Since the coefficient for the GPA/IQ interaction
# term is very small, there is very little evidence of an interaction
# effect. Justify your answer.

# %% [markdown]
# - False, even though interaction term is small it can be still significant, we should check p-values to determine the significance.

# %% [markdown]
# 4. I collect a set of data (n = 100 observations) containing a single
# predictor and a quantitative response. I then fit a linear regression
# model to the data, as well as a separate cubic regression, i.e. Y =
# β0 + β1X + β2X2 + β3X3 + ϵ.
#
# (a) Suppose that the true relationship between X and Y is linear,
# i.e. Y = β0 + β1X + ϵ. Consider the training residual sum of
# squares (RSS) for the linear regression, and also the training
# RSS for the cubic regression. Would we expect one to be lower
# than the other, would we expect them to be the same, or is there
# not enough information to tell? Justify your answer.

# %% [markdown]
#     - We would expect that cubic regression has much lower RSS with training data, because the model is much more flexible to fit the data.

# %% [markdown]
# (b) Answer (a) using test rather than training RSS.
#
#     - With test data we would expect linear regression to have lower RSS, because the relationship is linear, and cubic regression might have overfit the model to training data.

# %% [markdown]
# (c) Suppose that the true relationship between X and Y is not linear,
# but we don’t know how far it is from linear. Consider the training
# RSS for the linear regression, and also the training RSS for the
# cubic regression. Would we expect one to be lower than the
# other, would we expect them to be the same, or is there not
# enough information to tell? Justify your answer.
#
#     - We would expect cubic regression to have lower RSS, because if the relationship is not linear, with cubic regression we can overfit to the training data to explain more.

# %% [markdown]
# (d) Answer (c) using test rather than training RSS.
#
#     - There is not enough information to answer this fully, if the relationship is highly non-linear we can expect cubic regression to perform better, but if its slightly non-linear, linear regression might give lower RSS.

# %% [markdown]
# ![ch03_5](ch03_5.png "equation")

# %% [markdown]
# 6. Using (3.4), argue that in the case of simple linear regression, the
# least squares line always passes through the point (¯x, y¯).

# %% [markdown]
# <img src="ch03_7.jpg" alt="equation" width="300">

# %% [markdown]
# 7. It is claimed in the text that in the case of simple linear regression
# of Y onto X, the R2 statistic (3.17) is equal to the square of the
# correlation between X and Y (3.18). Prove that this is the case. For
# simplicity, you may assume that x¯ = ¯ y = 0.

# %% [markdown]
# <img src="ch03_8.jpg" alt="equation" width="300">
